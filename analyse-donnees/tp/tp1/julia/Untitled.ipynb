# %%
using ImageView, Images
I = load("ishihara-0.png");

# %%
using ImageMagick

# %%
I = load("ishihara-0.png");

# %%
RGBA.(I)
# Out:
# 1536×1985 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
# ...

# %%
R = red.(I);
G = green.(I);
B = blue.(I);

# %%
Gray.(R)
Gray.(G)
Gray.(B)
# Out:
# 1536×1985 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
# ...

# %%
X = [vec(R), vec(G), vec(B)]
# Out:
# 3-element Array{Array{Normed{UInt8,8},1},1}:
#  [1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8  …  1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8]
#  [1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8  …  1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8]
#  [1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8  …  1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8, 1.0N0f8]

# %%
size(X)
# Out:
# (3,)

# %%
size(vec(R))
# Out:
# (3048960,)

# %%
minimum(R)
# Out:
# 0.612N0f8

# %%
using Statistics

# %%
cov(X)
